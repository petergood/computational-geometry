# %% [markdown]
# # Sweep line algorithm

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from visualisation import *
from sweepline import *
from datasets import *

# %%
random_segments = generate_lines((-100, -100), (100, 100), 10)
random_segments
# Out:
# [[(-36, 22), (-88, 87)],
#  [(22, -91), (-74, -5)],
#  [(-6, 63), (79, -21)],
#  [(-58, -19), (-87, -73)],
#  [(83, -78), (87, 97)],
#  [(-84, -51), (-41, -90)],
#  [(48, 66), (53, 77)],
#  [(-25, -99), (80, -95)],
#  [(32, -7), (50, -100)],
#  [(-52, 39), (35, -42)]]

# %%
plot = Plot([Scene(lines=[LinesCollection(random_segments)])])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
segments = []
for segment in random_segments:
    segments.append(Segment(Point(segment[0][0], segment[0][1]), Point(segment[1][0], segment[1][1])))

# %%
intersection_points = sweep(segments)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-a14edad5f697> in <module>
# ----> 1 intersection_points = sweep(segments)
#
# ~/Documents/github/petergood/computational-geometry/sweepline/sweepline.py in sweep(segments)
#     193         elif event.event_type == EventType.END:
#     194             segment = involved_segments[0]
# --> 195             upper_neighbour = sweep_line.upper_neighbour(segment)
#     196             lower_neighbour = sweep_line.lower_neighbour(segment)
#     197             sweep_line.remove(segment)
#
# ~/Documents/github/petergood/computational-geometry/sweepline/sweepline.py in upper_neighbour(self, segment)
#     157
#     158     def upper_neighbour(self, segment):
# --> 159         index = self.status.index(StatusSegmentWrapper(segment))
#     160         if index == len(self.status) - 1:
#     161             return None
#
# ...
